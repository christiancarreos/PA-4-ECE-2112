# %% [markdown]
# ## EXPERIMENT 4
# DATA WRANGLING AND DATA VISUALIZATION

# %% [markdown]
# ### ECE BOARD EXAM PROBLEM:
# Using data wrangling and data visualization technique with
# storytelling, analyze the data and present different (i) data frames; and (ii) visuals using the dataset given.

# %% [markdown]
# #### Filename: Instru = [“Name”, “GEAS”, “Electronics >70”];
# where track is constant as
# Instrumentation and hometown Luzon

# %%
# Import pandas as the main library for this code
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the downloaded csv file
boardexam = pd.read_csv('board2.csv')
boardexam
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %% [markdown]
# ### 1. Create the following data frames based on the format provided:
# Example: Vis = [“Name”, “Gender”, “Track”, “Math<70”]; hometown is constant as Visayas

# %%
# Display the DataFrame and use Vis as name by locating the data from the csv file matching the certain conditions given.
Vis = boardexam.loc[ (boardexam['Hometown'] == 'Visayas') & (boardexam['Math'] < 70), ['Name', 'Gender', 'Track', 'Math']]
Vis
# Out:
#    Name  Gender            Track  Math
# 3    S4    Male  Instrumentation    65
# 10  S11  Female    Communication    48
# 21  S22  Female    Communication    64

# %% [markdown]
# a. Filename: Instru = [“Name”, “GEAS”, “Electronics >70”]; where track is constant as
# Instrumentation and hometown Luzon

# %%
# Display the DataFrame and use Instru as name by locating the data from the csv file matching the certain conditions given.
Instru = boardexam.loc[ (boardexam['Track'] == 'Instrumentation') & (boardexam['Hometown'] == 'Luzon') & (boardexam['Electronics'] > 70), ['Name', 'Electronics', 'GEAS']]
Instru
# Out:
#    Name  Electronics  GEAS
# 0    S1           89    75
# 7    S8           81    64
# 29  S30           81    57

# %% [markdown]
# b. Filename: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is
# constant as Mindanao and gender Female

# %%
# Display the DataFrame and use Mindy as name by locating the data from the csv file matching the certain conditions given.
boardexam['Average'] = boardexam[['Electronics', 'GEAS', 'Math', 'Communication']].mean(axis=1)
Mindy = boardexam.loc[(boardexam['Hometown'] == 'Mindanao') & 
                      (boardexam['Gender'] == 'Female'), 
                      ['Name', 'Track', 'Electronics', 'Average']]
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %% [markdown]
# 2. Create a visualization that shows how the different features contributes to average grade. Does
# chosen track in college, gender, or hometown contributes to a higher average score?
# Name: Surname, First Name MI.
# Section: 2ECE-X Date Submitted: January X, 202X

# %%
# Create a bar graph that visualizes the data gathered from the csv file
# The graph helps to visualize the correlation of each categories to the Average
combinedavg = data.groupby(['Track', 'Gender', 'Hometown'])['Average'].mean().unstack()
print("\nCombined Average Grade by Track, Gender, and Hometown:")
print(combined_avg)

fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Average Grade by Track
data.groupby('Track')['Average'].mean().plot(kind='bar', ax=axes[0], color='darkblue', title='Average Grade by Track', ylabel='Average Grade')

# Average Grade by Gender
data.groupby('Gender')['Average'].mean().plot(kind='bar', ax=axes[1], color='pink', title='Average Grade by Gender', ylabel='Average Grade')

# Average Grade by Hometown
data.groupby('Hometown')['Average'].mean().plot(kind='bar', ax=axes[2], color='violet', title='Average Grade by Hometown', ylabel='Average Grade')

# Adjust layout
plt.tight_layout()

# Show the combined plot
plt.show()
# Out:
# Combined Average Grade by Track, Gender, and Hometown:
# Hometown                  Luzon  Mindanao    Visayas
# Track            Gender
# Communication    Female  77.250    66.875  58.625000
#                  Male    72.125       NaN  69.083333
# Instrumentation  Female  58.500    72.750  65.750000
#                  Male    64.250    63.500  70.500000
# Microelectronics Female  71.375    64.750  67.250000
#                  Male    73.000    67.250  60.750000
